# %%
import requests

BASE_URL = "https://us-central1-aecincode.cloudfunctions.net/flask-app-func" #"http://localhost:5000"

requests.get(f"{BASE_URL}/").json()
# Out:
# {'message': 'Hello from Flask boilerplate'}

# %%
requests.get(f"{BASE_URL}/health").json()
# Out:
# {'status': 'ok'}

# %%
a = requests.post(f"{BASE_URL}/echo", json={"key": "value"})
print(a)
# Out:
# <Response [200]>

# %%
a.json()
# Out:
# {'key': 'value'}

# %%
requests.get(f"{BASE_URL}/test", params={"lat": 40.7128, "lon": -74.0060}).json()
# Out:
# {'message': '345', 'status': 'ok'}
